# %%
import pandas as pd
import numpy as np
from pathlib import Path

# ---- Load CSV ----
src = Path("astronauts.csv")
df = pd.read_csv(src)

# ---- Name Reformatting ----
def reformat_name(name):
    if pd.isna(name):
        return name
    s = str(name).strip()

    # Handle leading suffix like "Jr." or "Sr."
    suffix = None
    if s.lower().endswith("Jr.") or s.lower().endswith("Sr."):
        print(s)
        parts = s.split(None, 1)  # split into ["Jr.", rest]
        suffix = parts[-1]
        s = parts[:-1] if len(parts) > 1 else ""

    if "," not in s:
        return s if not suffix else f"{s} {suffix}"

    last, rest = s.split(",", 1)
    last = last.strip()
    rest = rest.strip()

    if not rest:
        return s if not suffix else f"{s} {suffix}"

    parts = rest.split()
    if len(parts) == 1:
        first = parts[0]
        middle_parts = []
    else:
        first = parts[-1]
        middle_parts = parts[:-1]

    new_parts = [first] + middle_parts + [last]
    if suffix:
        new_parts.append(suffix)

    return " ".join(p for p in new_parts if p)

# Apply name cleaning
df["Profile.Name"] = df["Profile.Name"].apply(reformat_name)

# ---- Roles Parsing ----
# Detect the roles column (contains "role" in its name)
role_col_candidates = [c for c in df.columns if "role" in c.lower()]
if not role_col_candidates:
    raise KeyError("No column found that looks like it contains astronaut roles.")
role_col = role_col_candidates[0]

def parse_roles(val):
    if pd.isna(val):
        return []
    s = str(val)
    if ";" in s:
        return [r.strip() for r in s.split(";") if r.strip()]
    if "," in s:
        return [r.strip() for r in s.split(",") if r.strip()]
    return [s.strip()]

# ---- Build dictionary ----
astronaut_roles = {}
for _, row in df.iterrows():
    name = row["Profile.Name"]
    roles = parse_roles(row[role_col])
    astronaut_roles[name] = roles

# ---- Example usage ----
print("Preview (first 10 entries):")
for i, (k, v) in enumerate(astronaut_roles.items()):
    if i >= 10: break
    print(f"{k}: {v}")
# Out:
# Yuri
# Gherman
# John H., Jr.
# John H., Jr.
# M. Scott
# Andriyan
# Andriyan
# Pavel
# Pavel
# Walter M., Jr.
# Walter M., Jr.
# Walter M., Jr.
# L. Gordon, Jr.
# L. Gordon, Jr.
# Valery
# Valery
# Valery
# Valentina
# Vladimir
# Vladimir
# Konstantin
# Boris
# Pavel
# Aleksei
# Aleksei
# Virgil I.
# John W.
# John W.
# John W.
# John W.
# John W.
# John W.
# James A.
# James A.
# Edward H., II
# Charles, Jr.
# Charles, Jr.
# Charles, Jr.
# Charles, Jr.
# Frank
# Frank
# James A., Jr.
# James A., Jr.
# James A., Jr.
# James A., Jr.
# Thomas P.
# Thomas P.
# Thomas P.
# Thomas P.
# Neil A.
# Neil A.
# David R.
# David R.
# David R.
# Eugene A.
# Eugene A.
# Eugene A.
# Michael
# Michael
# Richard F., Jr.
# Richard F., Jr.
# Edwin Eugene, Jr.
# Edwin Eugene, Jr.
# Donn F.
# Ronnie Walter
# Viktor
# Viktor
# Robert L.
# Robert L.
# Robert L.
# Robert L.
# Joe H.
# Joe H.
# Richard N.
# Richard N.
# James C.
# James C.
# Mark N.
# Mark N.
# Michael J.
# Ellen S.
# Ellen S.
# Ellen S.
# Manley Lanier, Jr.
# Kathryn C.
# Kathryn C.
# Kathryn C.
# Kathryn C.
# James D.
# James D.
# James D.
# James D.
# James D.
# James D.
# Marsha S.
# Marsha S.
# Marsha S.
# Marsha S.
# Marsha S.
# G. David
# G. David
# G. David
# Aleksandr
# John H.
# John H.
# John H.
# John H.
# Pierre J.
# Pierre J.
# Pierre J.
# Gennadi
# Gennadi
# Robert D.
# Robert D.
# Robert D.
# Robert D.
# Bruce E.
# Bruce E.
# Thomas D.
# Thomas D.
# Thomas D.
# Thomas D.
# Frank L., Jr.
# Frank L., Jr.
# Frank L., Jr.
# Carl J.
# Carl J.
# Carl J.
# Charles D.
# Charles D.
# Charles D.
# Samuel Thornton
# Samuel Thornton
# Ronald Anthony
# Ronald Anthony
# Viktor Mikhaylovich
# Viktor Mikhaylovich
# Viktor Mikhaylovich
# Viktor Mikhaylovich
# Toyohiro
# Kenneth D.
# Kenneth D.
# Kenneth D.
# Linda M.
# Linda M.
# Linda M.
# Linda M.
# Jerome
# Jerome
# Jerome
# Jerome
# L. Blaine, Jr.
# L. Blaine, Jr.
# Gregory J.
# Gregory J.
# Gregory J.
# Gregory J.
# Donald R.
# Donald R.
# Donald R.
# Charles Lacy
# Charles Lacy
# Richard J.
# Richard J.
# Richard J.
# Anatoly
# Sidney M.
# Sidney M.
# Tamara E.
# Tamara E.
# Tamara E.
# Tamara E.
# Tamara E.
# Andrew
# Millie Elizabeth
# Michael A.
# Michael A.
# Michael A.
# Michael A.
# Kenneth S., Jr.
# Kenneth S., Jr.
# Toktar
# Franz
# Terence T.
# Terence T.
# Terence T.
# Terence T.
# James S.
# James S.
# James S.
# James S.
# James S.
# Mario, Jr.
# Mario, Jr.
# Mario, Jr.
# Thomas John
# Stephen S.
# Stephen S.
# Stephen S.
# William F.
# William F.
# William F.
# Roberta Lynn
# Aleksandr
# Aleksandr
# Aleksandr
# Aleksandr
# Aleksandr
# Klaus-Dietrich
# Brian
# Brian
# Brian
# Brian
# C. Michael
# C. Michael
# C. Michael
# C. Michael
# C. Michael
# C. Michael
# David
# Kevin P.
# Kevin P.
# Kevin P.
# Kenneth D.
# Kenneth D.
# Kenneth D.
# Kenneth D.
# Kenneth D.
# Lawrence James
# Eugene Huu-Chau
# Sergei
# Sergei
# Sergei
# Michel
# Michel
# Andrew M.
# Andrew M.
# Andrew M.
# Claude
# Claude
# Claude
# Claude
# Curtis L., Jr.
# Curtis L., Jr.
# Curtis L., Jr.
# Curtis L., Jr.
# Curtis L., Jr.
# Curtis L., Jr.
# Nancy Jan
# Nancy Jan
# Nancy Jan
# Mae C.
# Mamoru
# Mamoru
# Michael R.
# Michael R.
# Michael R.
# Susan J.
# Susan J.
# Susan J.
# Susan J.
# Susan J.
# Aleksandr
# Kenneth D.
# Kenneth D.
# Kenneth D.
# Kenneth D.
#
# Pavel
# Pavel
# Robert L., Jr.
# Robert L., Jr.
# Robert L., Jr.
# Stephen K.
# Stephen K.
# Stephen K.
# Stephen K.
# Michael J.
# Michael J.
# Michael J.
# Steven W.
# Steven W.
# Steven W.
# Steven W.
# Steven W.
# Kalpana
# Kalpana
# Takao
# Takao
# Leonid
# Joe F., Jr.
# James F.
# James F.
# James F.
# Michael P.
# Michael P.
# Salizhan
# Salizhan
# Lopold
# Lopold
# Scott D.
# Scott D.
# Scott D.
# Scott D.
# Kathryn P.
# Kathryn P.
# Dafydd Rhys
# Dafydd Rhys
# Jay Clark Jr.
# James Anthony
# Dominic L.
# Dominic L.
# Dominic L.
# Dominic L.
# Janet L.
# Janet L.
# Janet L.
# Gennady
# Gennady
# Gennady
# Gennady
# Gennady
# Yuri
# Pedro
# Yuri
# Pedro
# Frederick W.
# Frederick W.
# Frederick W.
# Frederick W.
# Ivan
# Rick D.
# Rick D.
# Julie
# Julie
# Valeri
# Valeri
# Jeffrey S.
# Jeffrey S.
# Jeffrey S.
# Scott J.
# Scott J.
# Scott J.
# Scott J.
# Gerhard
# Sergei
# Sergei
# Jeffrey N.
# Jeffrey N.
# Jeffrey N.
# Jeffrey N.
# Richard A.
# Richard A.
# Richard A.
# Richard A.
# Daniel C.
# Daniel C.
# Daniel C.
# Boris
# Pamela A.
# Pamela A.
# Pamela A.
# Mark L.
# Mark L.
# Mark L.
# James M.
# James M.
# Paul W.
# John L.
# John L.
# John L.
# Yuri
# Yuri
# Yuri
# Dennis Anthony
# Charles O.
# Charles O.
# Charles O.
# Patrick G.
# Patrick G.
# Patrick G.
# Mikhail
# Mikhail
# Mikhail
# Konstantin
# Mark E.
# Mark E.
# Mark E.
# Mark E.
# Daniel M.
# Daniel M.
# Duane G.
# Michael J.
# Michael J.
# Stephen N.
# Stephen N.
# Rex J.
# Rex J.
# Rex J.
# Lee M.
# Roverto
# Roverto
# Roverto
# M. Richard
# Paul S.
# Paul S.
# Philippe
# Peggy A.
# Peggy A.
# Peggy A.
# Sergei
# Sandra H.
# Sandra H.
# Sandra H.
# Piers J.
# Piers J.
# Piers J.
# Fyodor
# Fyodor
# Fyodor
# Fyodor
# Fyodor
# Frank
# Frank
# John B.
# Donald R.
# Donald R.
# Donald R.
# William C.
# David M.
# Laurel B.
# Ilan
# Liwei
# E. Michael
# E. Michael
# E. Michael
# Andre
# Andre
# Yuri
# Soichi
# Soichi
# Charles J.
# Junlong
# Marcos Cesar
# Michael E.
# Michael E.
# Michael E.
# Lisa M.
# Stephanie D.
# Stephanie D.
# Stephanie D.
# Christopher J.
# Christopher J.
# Christopher J.
# Heidemarie M.
# Heidemarie M.
# William A.
# Nicholas J. M.
# Nicholas J. M.
# Joan E.
# Sunita L.
# Sunita L.
# Oleg
# Oleg
# Oleg
# Lee J.
# Lee J.
# Steven R.
# Steven R.
# Steven R.
# John D.
# John D.
# Clayton C.
# Clayton C.
# Tracy E.
# Tracy E.
# Alvin Benjamin
# Alvin Benjamin
# Barbara R.
# Sheikh Muszaphar
# George D.
# George D.
# Douglas H.
# Douglas H.
# Paolo A.
# Paolo A.
# Paolo A.
# Alan G.
# Alan G.
# Leland D.
# Leland D.
# Stanley G.
# Gregory H.
# Gregory H.
# Robert L.
# Robert L.
# Michael J.
# Michael J.
# Garrett E.
# Garrett E.
# Sergei
# Sergei
# Sergei
# Oleg D.
# Oleg D.
# Oleg D.
# Oleg D.
# Soyeon (Lee So-hyun)
# Kenneth T.
# Kenneth T.
# Karen L.
# Karen L.
# Ronald J., Jr.
# Ronald J., Jr.
# Akihiko
# Akihiko
# Gregory
# Gregory
# Zhigang
# Boming
# Haipeng
# Haipeng
# Haipeng
# Eric A.
# Eric A.
# Stephen G.
# Stephen G.
# Stephen G.
# Robert S.
# Robert S.
# Dominic A.
# Dominic A.
# Joseph M.
# Joseph M.
# Joseph M.
# Richard R., II
# Richard R., II
# Michael R.
# Michael R.
# Gregory C.
# Michael T.
# Michael T.
# K. Megan
# Andrew J.
# Andrew J.
# Andrew J.
# Roman
# Roman
# Douglas G.
# Douglas G.
# Christopher J.
# Christopher J.
# Thomas H.
# Thomas H.
# Timothy L.
# Timothy L.
# Kevin A.
# Kevin A.
# Jose M.
# Nicole P.
# Nicole P.
# Maksim
# Maksim
# Barry E.
# Barry E.
# Randolph J.
# Randolph J.
# Robert L.
# Timothy J.
# Terry W., Jr.
# Terry W., Jr.
# Aleksandr Jr.
# Aleksandr Jr.
# Aleksandr Jr.
# Mikhail
# Mikhail
# James P.
# Dorothy M.
# Naoko
# Shannon
# Oleg
# Oleg
# Oleg
# Dmitri
# Aleksandr
# Aleksandr
# Andrei
# Andrei
# Satoshi
# Anton
# Anton
# Anton
# Anatoli
# Anatoli
# Sergei
# Wang
# Yang
# Oleg
# Oleg
# Yevgeni
# Aleksandr
# Aleksandr
# Luca
# Xiaoguang
# Yapi
# Sergei
# Sergei
# Michael Scott
# Oleg
# Oleg
# Gregory Reid
# Alexander
# Alexander
# Yelena
# Samantha
# Kimiya
# Kjell Norwood
# Andreas
# Timothy Nigel
# Aleksey
# Aleksey
# Aleksey
# Takuya
# Kathleen
# Dong
# Sergey
# Thomas
# Jack
# Mark
# Scott
# Norishige
# Sergei
# Serena
# Tyler
# Tyler
# David
# Anne Charlotte
# Christina
# Andrew
# Jessica
# Hazzaa
# Preview (first 10 entries):
# Yuri Gagarin: ['pilot']
# Gherman Titov: ['pilot']
# Jr. John H., Glenn: ['PSP']
# Scott M. Carpenter: ['Pilot']
# Andriyan Nikolayev: ['pilot']
# Pavel Popovich: ['commander']
# Jr. Walter M., Schirra: ['commander']
# Jr. L. Gordon, Cooper: ['commander']
# Valery Bykovsky: ['commander']
# Valentina Tereshkova: ['pilot']
